# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # LINE GRAPH

# %%
df=sns.load_dataset('tips')
sns.lineplot(x="total_bill",y='size',data=df,hue='sex',linestyle='solid',legend='auto')
# Out:
# <Axes: xlabel='total_bill', ylabel='size'>

# %% [markdown]
# # BAR GRAPH

# %%
sns.barplot(x='day', y='total_bill', hue='sex', data=df, palette="rainbow")
plt.xlabel('Day of the week')
plt.ylabel('Total Bill')
plt.title('Total Bill by Day and Gender')
# Out:
# Text(0.5, 1.0, 'Total Bill by Day and Gender')

# %%
avg_total_bill = df.groupby('time') ['total_bill'].mean() 
avg_tip =df.groupby('time')['tip'].mean()
p1= plt.bar(avg_total_bill.index, avg_total_bill, label='Total Bill', width=0.4)
p2= plt.bar(avg_tip.index, avg_tip, bottom =avg_total_bill, label='Tip', width=0.4)
plt.xlabel('Time of Day')
plt.ylabel('Amount')
plt.title('Average Total Bill and Tip by Time of Day')
plt.legend()

# %%
sns.scatterplot(x='total_bill',y='tip',hue='sex',data=df)
plt.xlabel("Total Bill")
plt.ylabel("Tip amt")
plt.title("Scatter plot")
# Out:
# Text(0.5, 1.0, 'Scatter plot')

# %%
import numpy as np
import pandas as pd
np.random.seed(1)
num_var= np.random.randn(1000)
num_var =pd.Series (num_var, name ="Numerical variable")
num_var
# Out:
# 0      1.624345
# 1     -0.611756
# 2     -0.528172
# 3     -1.072969
# 4      0.865408
#          ...
# 995   -0.116444
# 996   -2.277298
# 997   -0.069625
# 998    0.353870
# 999   -0.186955
# Name: Numerical variable, Length: 1000, dtype: float64

# %%
sns.histplot(data=num_var,kde=True)
# Out:
# <Axes: xlabel='Numerical variable', ylabel='Count'>

# %%
np.random.seed(0)
marks=np.random.normal(loc=70, scale=10, size=100) 
marks
# Out:
# array([87.64052346, 74.00157208, 79.78737984, 92.40893199, 88.6755799 ,
#        60.2272212 , 79.50088418, 68.48642792, 68.96781148, 74.10598502,
#        71.44043571, 84.54273507, 77.61037725, 71.21675016, 74.43863233,
#        73.33674327, 84.94079073, 67.94841736, 73.13067702, 61.45904261,
#        44.47010184, 76.53618595, 78.64436199, 62.5783498 , 92.69754624,
#        55.45634325, 70.45758517, 68.1281615 , 85.32779214, 84.6935877 ,
#        71.54947426, 73.7816252 , 61.12214252, 50.19203532, 66.52087851,
#        71.56348969, 82.30290681, 82.02379849, 66.12673183, 66.97697249,
#        59.51447035, 55.79982063, 52.93729809, 89.50775395, 64.90347818,
#        65.61925698, 57.4720464 , 77.77490356, 53.86102152, 67.8725972 ,
#        61.04533439, 73.86902498, 64.89194862, 58.19367816, 69.71817772,
#        74.28331871, 70.66517222, 73.02471898, 63.65677906, 66.37258834,
#        63.27539552, 66.40446838, 61.86853718, 52.73717398, 71.77426142,
# ...

# %%
sns.histplot(data=marks, bins=10, kde =True, stat='count', cumulative=False, multiple='stack', element ='bars', palette='Seti', shrink=0.7)
plt.xlabel('Harks')
plt.ylabel("Density")
plt.title("Histogram of Students Marks")
# Out:
# C:\Users\SEC\AppData\Local\Temp\ipykernel_2928\3593888000.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=marks, bins=10, kde =True, stat='count', cumulative=False, multiple='stack', element ='bars', palette='Seti', shrink=0.7)
# Text(0.5, 1.0, 'Histogram of Students Marks')

# %%
sns.boxplot(x=df['smoker'],y=df['total_bill'],hue=df['sex'])
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
sns.boxplot (x="day", y="total_bill", hue="smoker", data=df, linewidth=2, width=0.6,boxprops={"facecolor": "red", "edgecolor": "blue"}, whiskerprops={"color": "black", "linestyle": "--", "linewidth": 1.5}, capprops={"color": "black", "linestyle": "--", "linewidth": 1.5})
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", hue="smoker", data=df,linewidth=2, width=0.6, palette="Blues", inner ="quartile")
plt.xlabel("Day of the Week")
plt.ylabel("Total Bill")
plt.title("violin Plot of Total Bill by Day and Smoker Status")
# Out:
# Text(0.5, 1.0, 'violin Plot of Total Bill by Day and Smoker Status')

# %%
sns.violinplot(x="tip", y="day",data=df,palette='rocket')
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
sns.kdeplot(data=df, x="total_bill",y='tip',palette='Set3')
# Out:
# C:\Users\SEC\AppData\Local\Temp\ipykernel_2928\3780751578.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(data=df, x="total_bill",y='tip',palette='Set3')
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.kdeplot(data=df, x="total_bill", bw_adjust=.2)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data=df, x="total_bill", hue="time", multiple="stack")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data=df, x="total_bill", hue="time", multiple="fill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data=df, x="total_bill", hue="time", multiple="layer")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>
